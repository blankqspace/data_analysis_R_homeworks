# %%
import pandas as pd

input_file = 'navi-eng-data-analysis.xlsx'
output_file = 'navi-eng-analysis.csv'

table = pd.read_excel(input_file, engine='openpyxl')
data = table.to_csv(output_file, index=False, encoding='utf-8-sig')

# %%
pd.read_csv("navi-eng-analysis.csv")
# Out:
#       id                                               navi  \
# 0      1                      Aylì'u ngian nì'it skepek lu.
# 1      2  Zìsìt amrr ftolia ohe, slä zene fko nivume nìt...
# 2      3  Zìsìt amrr ftolia ohe, slä zene fko nivume nìt...
# 3      4  Zìsìt amrr ftolia ohe, slä zene fko nivume nìt...
# 4      5                 Hu nawma sa'nok tivul ngeyä tirea.
# ..   ...                                                ...
# 96    97                         Muvea niktsyey lu ftxìlor.
# 97    98                                        Oe yäpolur.
# 98    99                                        Oe yäpolur.
# 99   100                                   Fkol oeti srätx.
# 100  101                                   Fkol oeti srätx.
#
#                                                     en target_verb     role  \
# 0            You still sound a bit too formal, though.   skepek lu    agent
# 1    I studied for five years but there is much to ...      ftolia    agent
# ...
